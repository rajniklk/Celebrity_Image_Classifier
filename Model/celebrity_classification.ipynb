# %% [markdown]
# <h2 style='color:blue' align='center'>Celebrity Image Classification<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/alia1.jpg')
img.shape
# Out:
# (900, 1200, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (900, 1200)

# %%
gray
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[343, 172, 343, 343]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (343, 172, 343, 343)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (343, 343, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/alia1.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/alia1.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/alia2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/alia2.jpg')
cropped_image_no_2_eyes
# Out:
# array([[[ 76,  76,  88],
#         [ 65,  65,  77],
#         [ 66,  66,  78],
#         ...,
#         [143, 153, 177],
#         [149, 154, 179],
#         [141, 146, 171]],
#
#        [[ 70,  70,  82],
#         [ 60,  60,  72],
#         [ 65,  65,  77],
#         ...,
#         [163, 173, 197],
#         [173, 178, 203],
#         [163, 168, 193]],
#
#        [[ 65,  65,  77],
#         [ 57,  57,  69],
#         [ 66,  66,  78],
#         ...,
#         [151, 161, 185],
#         [169, 174, 199],
#         [164, 169, 194]],
#
#        ...,
#
#        [[ 41,  52,  84],
#         [ 41,  53,  87],
#         [ 37,  51,  87],
#         ...,
#         [  0,   0,  24],
#         [  0,   3,  27],
#         [  5,  10,  31]],
#
#        [[ 41,  51,  85],
#         [ 43,  55,  91],
#         [ 37,  51,  87],
#         ...,
#         [  0,   4,  25],
#         [  0,   0,  21],
#         [  6,  12,  31]],
#
#        [[ 44,  54,  88],
#         [ 45,  57,  93],
#         [ 39,  52,  90],
#         ...,
#         [  6,   9,  30],
#         [  0,   0,  16],
#         [ 13,  20,  37]]], dtype=uint8)

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Alia_Bhatt',
#  './dataset/Deepika_Padukone',
#  './dataset/Hrithik_Roshan',
#  './dataset/Shahrukh_Khan',
#  './dataset/Yash']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Alia_Bhatt
# Generating cropped images in folder:  ./dataset/cropped/Deepika_Padukone
# Generating cropped images in folder:  ./dataset/cropped/Hrithik_Roshan
# Generating cropped images in folder:  ./dataset/cropped/Shahrukh_Khan
# Generating cropped images in folder:  ./dataset/cropped/Yash

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Alia_Bhatt': ['./dataset/cropped/Alia_Bhatt\\Alia_Bhatt1.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt10.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt100.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt101.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt102.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt103.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt104.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt105.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt106.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt107.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt108.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt109.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt11.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt110.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt111.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt112.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt113.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt115.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt116.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt117.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt118.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt119.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt12.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt120.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt121.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt122.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt123.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt124.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt125.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt126.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt127.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt128.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt129.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt13.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt130.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt131.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt132.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt133.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt134.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt135.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt136.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt137.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt139.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt14.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt140.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt141.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt142.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt143.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt144.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt145.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt147.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt15.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt151.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt152.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt153.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt155.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt156.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt157.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt158.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt159.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt16.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt160.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt161.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt162.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt163.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt164.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt165.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt166.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt167.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt169.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt17.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt170.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt171.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt172.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt173.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt174.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt175.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt176.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt177.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt178.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt179.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt18.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt180.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt181.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt183.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt184.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt185.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt186.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt187.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt188.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt189.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt19.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt191.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt192.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt193.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt194.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt195.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt197.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt198.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt199.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt2.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt20.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt200.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt201.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt202.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt203.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt205.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt206.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt207.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt208.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt209.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt21.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt211.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt212.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt213.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt215.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt216.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt217.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt218.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt219.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt22.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt23.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt24.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt25.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt26.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt27.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt28.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt29.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt3.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt30.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt31.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt32.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt33.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt34.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt35.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt36.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt37.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt38.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt4.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt40.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt41.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt42.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt43.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt45.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt46.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt47.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt48.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt49.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt50.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt51.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt52.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt53.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt54.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt55.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt56.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt57.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt58.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt59.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt6.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt60.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt61.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt62.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt63.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt64.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt65.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt66.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt67.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt68.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt69.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt7.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt70.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt71.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt72.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt73.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt74.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt75.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt76.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt77.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt78.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt79.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt8.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt80.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt81.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt82.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt83.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhatt84.png',
#   './dataset/cropped/Alia_Bhatt\\Alia_Bhat
png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan32.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan33.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan34.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan35.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan36.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan37.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan38.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan39.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan4.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan40.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan41.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan42.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan43.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan44.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan45.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan46.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan47.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan48.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan5.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan50.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan51.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan53.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan54.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan55.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan56.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan57.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan58.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan59.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan6.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan60.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan61.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan62.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan63.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan64.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan65.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan67.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan68.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan69.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan7.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan70.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan71.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan72.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan73.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan74.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan75.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan76.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan77.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan78.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan79.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan8.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan80.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan81.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan82.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan85.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan86.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan87.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan88.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan89.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan9.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan90.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan91.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan93.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan94.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan95.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan96.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan97.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan98.png',
#   './dataset/cropped/Shahrukh_Khan\\Shahrukh_Khan99.png'],
#  'Yash': ['./dataset/cropped/Yash\\Yash100.png',
#   './dataset/cropped/Yash\\Yash102.png',
#   './dataset/cropped/Yash\\Yash103.png',
#   './dataset/cropped/Yash\\Yash105.png',
#   './dataset/cropped/Yash\\Yash106.png',
#   './dataset/cropped/Yash\\Yash107.png',
#   './dataset/cropped/Yash\\Yash108.png',
#   './dataset/cropped/Yash\\Yash11.png',
#   './dataset/cropped/Yash\\Yash12.png',
#   './dataset/cropped/Yash\\Yash13.png',
#   './dataset/cropped/Yash\\Yash14.png',
#   './dataset/cropped/Yash\\Yash15.png',
#   './dataset/cropped/Yash\\Yash18.png',
#   './dataset/cropped/Yash\\Yash19.png',
#   './dataset/cropped/Yash\\Yash20.png',
#   './dataset/cropped/Yash\\Yash21.png',
#   './dataset/cropped/Yash\\Yash22.png',
#   './dataset/cropped/Yash\\Yash24.png',
#   './dataset/cropped/Yash\\Yash25.png',
#   './dataset/cropped/Yash\\Yash27.png',
#   './dataset/cropped/Yash\\Yash3.png',
#   './dataset/cropped/Yash\\Yash31.png',
#   './dataset/cropped/Yash\\Yash32.png',
#   './dataset/cropped/Yash\\Yash34.png',
#   './dataset/cropped/Yash\\Yash35.png',
#   './dataset/cropped/Yash\\Yash39.png',
#   './dataset/cropped/Yash\\Yash41.png',
#   './dataset/cropped/Yash\\Yash42.png',
#   './dataset/cropped/Yash\\Yash45.png',
#   './dataset/cropped/Yash\\Yash5.png',
#   './dataset/cropped/Yash\\Yash50.png',
#   './dataset/cropped/Yash\\Yash51.png',
#   './dataset/cropped/Yash\\Yash52.png',
#   './dataset/cropped/Yash\\Yash53.png',
#   './dataset/cropped/Yash\\Yash57.png',
#   './dataset/cropped/Yash\\Yash59.png',
#   './dataset/cropped/Yash\\Yash61.png',
#   './dataset/cropped/Yash\\Yash63.png',
#   './dataset/cropped/Yash\\Yash64.png',
#   './dataset/cropped/Yash\\Yash66.png',
#   './dataset/cropped/Yash\\Yash68.png',
#   './dataset/cropped/Yash\\Yash69.png',
#   './dataset/cropped/Yash\\Yash71.png',
#   './dataset/cropped/Yash\\Yash72.png',
#   './dataset/cropped/Yash\\Yash73.png',
#   './dataset/cropped/Yash\\Yash75.png',
#   './dataset/cropped/Yash\\Yash77.png',
#   './dataset/cropped/Yash\\Yash79.png',
#   './dataset/cropped/Yash\\Yash8.png',
#   './dataset/cropped/Yash\\Yash81.png',
#   './dataset/cropped/Yash\\Yash82.png',
#   './dataset/cropped/Yash\\Yash85.png',
#   './dataset/cropped/Yash\\Yash87.png',
#   './dataset/cropped/Yash\\Yash89.png',
#   './dataset/cropped/Yash\\Yash9.png',
#   './dataset/cropped/Yash\\Yash90.png',
#   './dataset/cropped/Yash\\Yash91.png',
#   './dataset/cropped/Yash\\Yash92.png',
#   './dataset/cropped/Yash\\Yash94.png',
#   './dataset/cropped/Yash\\Yash96.png',
#   './dataset/cropped/Yash\\Yash97.png',
#   './dataset/cropped/Yash\\Yash98.png',
#   './dataset/cropped/Yash\\Yash99.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Alia_Bhatt': 0,
#  'Deepika_Padukone': 1,
#  'Hrithik_Roshan': 2,
#  'Shahrukh_Khan': 3,
#  'Yash': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[164],
#        [181],
#        [200],
#        ...,
#        [  2],
#        [  4],
#        [ 28]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (636, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8805031446540881

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92        46
#            1       0.86      0.93      0.89        40
#            2       0.85      0.88      0.86        25
#            3       0.84      0.87      0.86        31
#            4       0.92      0.71      0.80        17
#
#     accuracy                           0.88       159
#    macro avg       0.88      0.86      0.87       159
# weighted avg       0.88      0.88      0.88       159

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.811382
# 1        random_forest    0.601776
# 2  logistic_regression    0.802895
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('svc',
#                   SVC(C=1, break_ties=False, cache_size=200, class_weight=None,
#                       coef0=0.0, decision_function_shape='ovr', degree=3,
#                       gamma='auto', kernel='linear', max_iter=-1,
#                       probability=True, random_state=None, shrinking=True,
#                       tol=0.001, verbose=False))],
#           verbose=False),
#  'random_forest': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='auto',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_impurity_split=None,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=10, n_jobs=None,
#                                          oob_score=False, random_state=None,
#                                          verbose=0, warm_start=False))],
#           verbose=False),
#  'logistic_regression': Pipeline(memory=None,
#           steps=[('standardscaler',
#                   StandardScaler(copy=True, with_mean=True, with_std=True)),
#                  ('logisticregression',
#                   LogisticRegression(C=1, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=100,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=None,
#                                      solver='liblinear', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False)}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8805031446540881

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5911949685534591

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8742138364779874

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[43,  1,  1,  1,  0],
#        [ 2, 35,  1,  2,  0],
#        [ 1,  1, 20,  2,  1],
#        [ 1,  0,  2, 28,  0],
#        [ 0,  1,  1,  1, 14]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Alia_Bhatt': 0,
#  'Deepika_Padukone': 1,
#  'Hrithik_Roshan': 2,
#  'Shahrukh_Khan': 3,
#  'Yash': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (0.14.1)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
